# %% [markdown]
# # Overview
#
# ---
#
# ## Order of Operations
#
# ### Introduction to Order of Operations
#
# - What is a variable? and What is the Order of Operations?
# - Examples 1-12: Simplifying using the Order of Operations
# - Examples 13-20: Evaluate each expression
# - Examples 21-24: Find the value of each expression
# - Examples 25: Evaluate the expression
#
# ### Real Numbers
#
# - Introduction to Video: Real Numbers and Number Sets
# - Overview of Number Sets
# - Diagram of the Number Sets and Symbols
# - Examples 1-7: Classify each number as: Natural, Whole, Integer, Rational, Irrational or Real
# - Examples 8-11: Name the set of numbers represented by the Number Line
# - Examples 12-15: Find the described coordinate
# - Opposites and Absolute Value
# - Examples 16-19: Identify the Opposite and Absolute Value for each number
# - Examples 20-31: Simplify
# - Examples 32-35: Write the numbers from least to greatest
# - Examples 36-39: Compare real numbers
#
# ### Translating Algebraic Expressions
#
# - Introduction to Video: Translating Algebraic Expressions and Equations
# - Key Words and Translations for Addition and Subtraction
# - Key Words and Translations for Multiplication and Division
# - Key Words and Translations for Parentheses, Powers and Equals
# - Examples 1-9: Translate algebraic expressions
# - Examples 10-15: Translate algebraic equation
# - Examples 16-19: Write an equation that represents the situation
#
# ### Algebraic Properties
#
# - Introduction to Video: Algebraic Properties
# - Overview of Reflexive, Symmetric, Transitive and Closure Properties
# - Overview of Commutative, Associative, Distributive, Inverse and Identity Properties
# - Examples 1-9: Name the property illustrated
# - Rules and Operations with Real Numbers
# - Examples 10-15: Evaluate each expression
#
# ### Multiplying and Dividing
#
# - Introduction to Video: Multiplication and Division Rules for Real Numbers
# - Property of Opposites and Why two negatives equal a positive?
# - Acronym NOPE for multiplication rules with Examples 1-6
# - Examples 7-11: Simplify using Multiplication Rules
# - Cancelation Rule for Fractions Properties of Division
# - Examples 12-23: Simplify using Multiplication and Division Rules
# - Examples 23-25: Evaluate each expression
#
# ### Combining Like Terms
#
# - Introduction to Video: Combining Like Terms
# - Overview How to Combine Like Terms with Examples 1-9
# - Examples 10-19: Simplify by Combining Like Terms
# - Using the Distributive Property to create Equivalent Algebraic Expressions
# - Examples 20-33: Simplify using the Distributive Property and Combine Like Terms
#
# ### Consecutive Integers
#
# - Introduction to Video: Consecutive Integers
# - Overview of Consecutive Integers and Notation
# - Examples 1-4: Write an expression involving Consecutive Integers
# - Examples 5-8: Write an equation involving Consecutive Integers
# - Examples 9-11: Write an equation that represents the stated relationship
#
# ### Chapter Test
#
# - Examples 1-7: Simplify using the Order of Operations
# - Examples 8-13: Simplify using the Order of Operations
# - Examples 14-18: Evaluate the expression
# - Examples 19-22: Translate the algebraic expression
# - Examples 23-29: Compare and Indicate the Number Set(s)
# - Examples 30-35: Name the Property (postulate) Illustrated
# - Examples 36-39: What is the Inverse Operation to isolate the variable?

# %% [markdown]
# # Introduction to Order of Operations
# ---
#
# - “evaluate the expression”? == “simplify” or “find the value.”
#
#
# - Expressions can be **numerical**, meaning they **only contain numbers**, or the can be **variable**, where there are _symbols or letters in the expression_ that represents **unknown number(s).**
#
#
# - *the way* in which we evaluate or simplify an expression is known as the *Order of Operations*, or *Operator Precedence.*
#
#
# - These rules tell us **which operations or procedures we are to perform first when evaluating a given mathematical expression.**
#
#
# - “operations” in mathematics refers to **addition, subtraction, multiplication, division, grouping, or any other mathematical process.**
